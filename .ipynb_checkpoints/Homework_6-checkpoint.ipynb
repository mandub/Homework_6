# %% [markdown]
# # Homework 6 (more of a tutorial, really)

# %% [markdown]
# As I was browsing through Kaggle the other day, I came upon a brand new dataset from the University of Puerto Rico, which contains images of bees entering their hive.  The task is to determine automatically which bees are carrying pollen.  Your job will be to develop a convolutional neural network that performs this task.

# %% [markdown]
# ## 1. Load Data (0 pts)

# %% [markdown]
# First, we need to load the bee data, which is included along with this homework.  Fortunately, the authors of the Kaggle dataset provided a nice set of files which will do this for us, which I have reproduced below

# %%
import glob, os 
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path="images/"
imlist= glob.glob(os.path.join(path, '*.jpg'))

# %%
def dataset(file_list,size=(300,180),flattened=False):
    data = []
    for i, file in enumerate(file_list):
        image = io.imread(file)
        image = transform.resize(image, size, mode='constant')
        if flattened:
            image = image.flatten()

        data.append(image)

    labels = [1 if f.split("/")[-1][0] == 'P' else 0 for f in file_list]

    return np.array(data), np.array(labels)

# %%
# Load the dataset (may take a few seconds)
X,y=dataset(imlist)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
# X has the following structure: X[imageid, y,x,channel]
print('X: ',X.shape)  # data
print('y: ',y.shape)  # target

print('Class 0: ',sum(y==0))
print('Class 1: ',sum(y==1))
print('Total  : ',len(y))
# Out:
# X:  (714, 300, 180, 3)
# y:  (714,)
# Class 0:  345
# Class 1:  369
# Total  :  714

# %% [markdown]
# We can plot a couple of the images below.  If you check out a couple of these, you will see that the visible difference when bees carry pollen is the presence of large fluffy balls of pollen on their back legs.

# %%
fig, axes = plt.subplots(1,2)
k=0
plt.sca(axes[0])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]))

k=401
plt.sca(axes[1])
plt.imshow(X[k])
plt.title('img {} - class {}'.format(k, y[k]));

# %% [markdown]
# ## 2. A convolutional network architecture for bee classification (40 pts)
#
# **Implement a 2D convolutional neural network using Keras.  You are free to choose whatever network architecture you like.**
#
# You can find all the relevant syntax for implementing such a network [here](https://github.com/keras-team/keras/blob/master/examples/mnist_cnn.py), the Keras convnet example for MNIST.
#
# *(For the sake of comparison, I will share the one that I used:*
#
# Layer 1: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 2: 4x4 Max-pooling layer
#
# Layer 3: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 4: 4x4 Max-pooling layer
#
# Layer 5: 5x5 convolution layer with 24 kernels and a relu activation function
#
# Layer 6: 4x4 Max-pooling layer
#
# Layer 7: Flattening layer
#
# Layer 8: Dropout layer with 0.2 dropout probability
#
# Layer 9: 1 node sigmoid layer

# %%
import keras
import keras.models as km
import keras.layers as kl

import numpy as np
N =1
input_shape = ((300,180,3))

model = km.Sequential()
#! Add layers to your convolutional neural network 

#Layer 1: 5x5 convolution layer with 24 kernels and a relu activation function
model.add(kl.Conv2D(24,kernel_size=(5,5),padding='same',activation='relu',input_shape=input_shape))

#Layer 2: 4x4 Max-pooling layer
model.add(kl.MaxPooling2D(pool_size=(4,4),padding='same'))

#Layer 3: 5x5 convolution layer with 24 kernels and a relu activation function
model.add(kl.Conv2D(24,kernel_size=(5,5),padding='same',activation='relu'))

#Layer 4: 4x4 Max-pooling layer
model.add(kl.MaxPooling2D(pool_size=(4,4),padding='same'))

#Layer 5: 5x5 convolution layer with 24 kernels and a relu activation function
model.add(kl.Conv2D(24,kernel_size=(5,5),padding='same',activation='relu'))

#Layer 6: 4x4 Max-pooling layer
model.add(kl.MaxPooling2D(pool_size=(4,4),padding='same'))

#Layer 7: Flattening layer
model.add(kl.Flatten())

#Layer 8: Dropout layer with 0.2 dropout probability
model.add(kl.Dropout(0.2))

#Layer 9: 1 node sigmoid layer
model.add(kl.Dense(N,activation='sigmoid'))

# %% [markdown]
# ## 3. Fitting the CNN to data (20 pts)
#
# Compile your model, using a binary crossentropy loss function and an optimizer of your choosing (RMSprop worked well for me).  Select a batch size and number of epochs, and fit your model to the training data, while also keeping track of the test set accuracy.
#
# **Plot the training and test accuracy of your model at each epoch.  Comment on whether you think the model is being overfit.**

# %%
model.compile(loss=keras.losses.binary_crossentropy,                #! Specify a loss function
              optimizer=keras.optimizers.RMSprop(),           #! Specify an optimizer
              metrics=['accuracy'])

batch_size = 32                       #! Specify a batch size
epochs= 32                            #! Specify an epoch  
history = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test,y_test))
# Out:
# Train on 571 samples, validate on 143 samples
# Epoch 1/32
# 571/571 [==============================] - 32s 56ms/step - loss: 0.3889 - acc: 0.8354 - val_loss: 0.2723 - val_acc: 0.8741
# Epoch 2/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.2585 - acc: 0.9002 - val_loss: 0.2602 - val_acc: 0.8951
# Epoch 3/32
# 571/571 [==============================] - 31s 55ms/step - loss: 0.2479 - acc: 0.8967 - val_loss: 0.2124 - val_acc: 0.9021
# Epoch 4/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.2138 - acc: 0.9142 - val_loss: 0.1883 - val_acc: 0.9371
# Epoch 5/32
# 571/571 [==============================] - 37s 65ms/step - loss: 0.1815 - acc: 0.9212 - val_loss: 0.1867 - val_acc: 0.9301
# Epoch 6/32
# 571/571 [==============================] - 34s 59ms/step - loss: 0.1941 - acc: 0.9177 - val_loss: 0.1714 - val_acc: 0.9301
# Epoch 7/32
# 571/571 [==============================] - 34s 59ms/step - loss: 0.1738 - acc: 0.9264 - val_loss: 0.1530 - val_acc: 0.9371
# Epoch 8/32
# 571/571 [==============================] - 36s 62ms/step - loss: 0.1634 - acc: 0.9352 - val_loss: 0.1750 - val_acc: 0.9371
# Epoch 9/32
# 571/571 [==============================] - 39s 69ms/step - loss: 0.1495 - acc: 0.9475 - val_loss: 0.1309 - val_acc: 0.9441
# Epoch 10/32
# 571/571 [==============================] - 34s 60ms/step - loss: 0.1516 - acc: 0.9457 - val_loss: 0.1287 - val_acc: 0.9650
# Epoch 11/32
# 571/571 [==============================] - 37s 64ms/step - loss: 0.1589 - acc: 0.9370 - val_loss: 0.1496 - val_acc: 0.9371
# Epoch 12/32
# 571/571 [==============================] - 36s 63ms/step - loss: 0.1248 - acc: 0.9492 - val_loss: 0.1849 - val_acc: 0.9231
# Epoch 13/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.0985 - acc: 0.9597 - val_loss: 0.1310 - val_acc: 0.9371
# Epoch 14/32
# 571/571 [==============================] - 34s 59ms/step - loss: 0.1149 - acc: 0.9597 - val_loss: 0.1803 - val_acc: 0.9301
# Epoch 15/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.1128 - acc: 0.9580 - val_loss: 0.1129 - val_acc: 0.9720
# Epoch 16/32
# 571/571 [==============================] - 34s 59ms/step - loss: 0.1063 - acc: 0.9580 - val_loss: 0.1165 - val_acc: 0.9650
# Epoch 17/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.0803 - acc: 0.9685 - val_loss: 0.1680 - val_acc: 0.9371
# Epoch 18/32
# 571/571 [==============================] - 34s 60ms/step - loss: 0.1047 - acc: 0.9597 - val_loss: 0.1329 - val_acc: 0.9650
# Epoch 19/32
# 571/571 [==============================] - 36s 62ms/step - loss: 0.0793 - acc: 0.9632 - val_loss: 0.1215 - val_acc: 0.9720
# Epoch 20/32
# 571/571 [==============================] - 34s 59ms/step - loss: 0.0866 - acc: 0.9685 - val_loss: 0.1202 - val_acc: 0.9720
# Epoch 21/32
# 571/571 [==============================] - 32s 57ms/step - loss: 0.0753 - acc: 0.9755 - val_loss: 0.1351 - val_acc: 0.9441
# Epoch 22/32
# 571/571 [==============================] - 35s 62ms/step - loss: 0.0882 - acc: 0.9755 - val_loss: 0.1336 - val_acc: 0.9720
# Epoch 23/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.0610 - acc: 0.9790 - val_loss: 0.1183 - val_acc: 0.9650
# Epoch 24/32
# 571/571 [==============================] - 34s 59ms/step - loss: 0.0710 - acc: 0.9807 - val_loss: 0.1107 - val_acc: 0.9720
# Epoch 25/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.0649 - acc: 0.9772 - val_loss: 0.1758 - val_acc: 0.9371
# Epoch 26/32
# 571/571 [==============================] - 38s 67ms/step - loss: 0.0650 - acc: 0.9720 - val_loss: 0.1268 - val_acc: 0.9720
# Epoch 27/32
# 571/571 [==============================] - 37s 64ms/step - loss: 0.0613 - acc: 0.9755 - val_loss: 0.1394 - val_acc: 0.9580
# Epoch 28/32
# 571/571 [==============================] - 37s 65ms/step - loss: 0.0633 - acc: 0.9737 - val_loss: 0.1166 - val_acc: 0.9720
# Epoch 29/32
# 571/571 [==============================] - 33s 58ms/step - loss: 0.0622 - acc: 0.9755 - val_loss: 0.1173 - val_acc: 0.9720
# Epoch 30/32
# 571/571 [==============================] - 35s 61ms/step - loss: 0.0336 - acc: 0.9912 - val_loss: 0.1482 - val_acc: 0.9580
# Epoch 31/32
# 571/571 [==============================] - 33s 59ms/step - loss: 0.0582 - acc: 0.9720 - val_loss: 0.1612 - val_acc: 0.9650
# Epoch 32/32
# 571/571 [==============================] - 33s 59ms/step - loss: 0.0288 - acc: 0.9930 - val_loss: 0.1473 - val_acc: 0.9650

# %%
#! Plot test and training accuracy (note that the history.
# history object is a dictionary containing relevant info)
# history.history.keys = acc loss val_acc val_loss
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()
counter =1
for i,j  in zip (history.history['acc'] , history.history['val_acc']):
    print (counter,'\t' ,i,'\t',j)
    counter +=1
# Out:
# 1 	 0.8353765316685946 	 0.8741258753763212
# 2 	 0.9001751316616706 	 0.8951048951048951
# 3 	 0.8966725036475788 	 0.9020979025147178
# 4 	 0.9141856395425814 	 0.9370629374797528
# 5 	 0.9211908927523317 	 0.9300699304867458
# 6 	 0.9176882672435139 	 0.9300699300699301
# 7 	 0.926444832894514 	 0.9370629370629371
# 8 	 0.9352014013639474 	 0.9370629374797528
# 9 	 0.9474605954465849 	 0.9440559444727598
# 10 	 0.9457092819614711 	 0.9650349654517807
# 11 	 0.936952713805197 	 0.9370629374797528
# 12 	 0.9492119082009939 	 0.9230769234937388
# 13 	 0.9597197908862459 	 0.9370629374797528
# 14 	 0.9597197908862459 	 0.9300699309035615
# 15 	 0.957968476357268 	 0.9720279724447878
# 16 	 0.957968476357268 	 0.9650349654517807
# 17 	 0.9684763565372461 	 0.9370629378965685
# 18 	 0.9597197908862459 	 0.965034965034965
# 19 	 0.9632224178564737 	 0.9720279724447878
# 20 	 0.968476357267951 	 0.9720279724447878
# 21 	 0.9754816122522705 	 0.9440559444727598
# 22 	 0.9754816112084063 	 0.9720279724447878
# 23 	 0.9789842392224981 	 0.9650349654517807
# 24 	 0.9807355516637478 	 0.9720279724447878
# 25 	 0.9772329239628152 	 0.9370629374797528
# 26 	 0.9719789842381786 	 0.9720279724447878
# 27 	 0.9754816122522705 	 0.9580419584587737
# 28 	 0.9737302977232924 	 0.9720279724447878
# 29 	 0.9754816112084063 	 0.9720279724447878
# 30 	 0.9912434325744308 	 0.9580419584587737
# 31 	 0.9719789852820429 	 0.9650349654517807
# 32 	 0.9929947460595446 	 0.9650349654517807

# %% [markdown]
# I think my model did not overfit that much but after 10 epochs we can see a gap start appear sometimes between training and test accuracy which may consider overfitting

# %% [markdown]
# ## 4. Model evaluation (20 pts)
#
# Now that you have a trained model, make a prediction for the test set (model.predict is a useful function for this).  **Compute and display a confusion matrix.  Select and display an example from the test set of a true positive, a true negative, a false positive, and a false negative.  Speculate on the reasons behind misclassification for images that your model predicted incorrectly**.

# %%
#! See above
from sklearn.metrics import confusion_matrix
P = model.predict(X_test)
model_predict = []
for i in P:
    if i >=.5:
        model_predict.append (1)
    else:
        model_predict.append (0)

con_matrix = confusion_matrix(y_test,model_predict)
print (con_matrix)
Accuracy= 1-sum(y_test!=model_predict)/len(y_test)
print ("Accuracy",Accuracy , "%")
# Out:
# [[68  3]
#  [ 2 70]]
# Accuracy 0.965034965034965 %

# %%
# pollen_carrying is positive
# not pollen_carrying is negative
ture_positive =[]
ture_negative =[]
false_positive = []
false_negative = [] 
for i in range (len(y_test)):
    if y_test[i]== model_predict[i]:
        if y_test[i] == 1:
            ture_positive.append(i)
        else:
            ture_negative.append(i)
    else:
        if y_test[i] == 1:
            false_positive.append(i)
        else:
            false_negative.append(i)

print ("-----------------True -------------------------")
plt.imshow(X_test[ture_positive[0]])
Title = 'ture_positive'
plt.title(Title, fontsize=10)
plt.show()
plt.imshow(X_test[ture_negative[0]])
Title = 'ture_negative'
plt.title(Title, fontsize=10)
plt.show()  

print ("-----------------False -------------------------")
plt.imshow(X_test[false_positive[1]])
Title = 'false_positive'
plt.title(Title, fontsize=10)
plt.show()
plt.imshow(X_test[false_negative[0]])
Title = 'false_negative'
plt.title(Title, fontsize=10)
plt.show()
# Out:
# -----------------True -------------------------
# -----------------False -------------------------

# %% [markdown]
# The image in false positive the color of the balloon and the bee body almost the same also it looks like it is from the bee body in this pictuer

# %% [markdown]
# The image in false negative the color of the middle bee body almost the same if there is a balloon there.
